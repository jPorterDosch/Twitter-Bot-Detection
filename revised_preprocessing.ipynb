# %%
# Automatically load changes in dependency files (may be unnecessary here, but useful tool in case you're modifying packages that this file relies on)
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder, MinMaxScaler


import os

# %%
# Recursive find for bot data from current directory
path = None
for dirpath, dirnames, filenames in os.walk("."):
    for dirname in dirnames:
        if dirname == "botometer-feedback-2019":
            path = os.path.join(dirpath, dirname)

assert path is not None, "botometer-feedback directory not found"
print(f"Path to csv file: {path}")

node_path = os.path.join(path, "node.json")
label_path = os.path.join(path, "label.csv")
# Out:
# Path to csv file: .\data\TwiBot22-Other-Datasets\Other-Dataset-TwiBot22-Format\botometer-feedback-2019

# %%
# Read in data into 2 dataframes and merge on the user id column
df_node = pd.read_json(node_path)
df_label = pd.read_csv(label_path)

df = pd.merge(df_node, df_label, on='id')

df
# Out:
#                    created_at  \
# 0   2012-06-07 22:16:27+00:00
# 1   2016-11-13 01:48:58+00:00
# 2   2012-10-18 23:19:38+00:00
# 3   2009-12-12 22:53:04+00:00
# 4   2008-10-22 13:43:42+00:00
# ..                        ...
# 513 2009-12-14 14:01:49+00:00
# 514 2009-01-30 12:31:25+00:00
# 515 2013-01-08 04:36:06+00:00
# 516 2012-12-03 14:58:40+00:00
# 517 2016-04-13 19:49:34+00:00
#
#                                            description  \
# 0    Strategic Creative Social Media & Community En...
# 1    Injustice and corruption make me really mad. I...
# 2    Whistler REALTOR® specializing in mountain lif...
# 3    O scrivi Italia o scrivi libertà. Due termini ...
# 4    Education, Flaneur, Digitalisation—Tweets Germ...
# ..                                                 ...
# 513  Drinker of coffee and player of games. Now als...
# 514  InfoSci PhD student. I research how we embed o...
# 515  Sports, Politics and Video Games. Bringing the...
# 516  it's hard being a single mother when you don't...
# 517  l believe in everything and right now I believ...
#
#                                               entities                   id  \
# 0    {'url': {'urls': [{'url': 'https://t.co/e5t6p9...           u602249341
# 1                        {'description': {'urls': []}}  u797617218511060992
# 2    {'url': {'urls': [{'url': 'http://t.co/7gh2Iu1...           u889925474
# 3                        {'description': {'urls': []}}            u96435556
# 4    {'url': {'urls': [{'url': 'https://t.co/VRgsX8...            u16905397
# ..                                                 ...                  ...
# 513  {'url': {'urls': [{'url': 'https://t.co/BgFtjC...            u96766049
# 514  {'url': {'urls': [{'url': 'https://t.co/80qIwR...            u19765236
# 515                      {'description': {'urls': []}}          u1069984033
# 516                      {'description': {'urls': []}}           u986789138
# 517                      {'description': {'urls': []}}  u720338157733068800
#
#                            location                                   name  \
# 0                   London - mostly                 Emma Dingle🐧🏳️‍🌈🇪🇺🇬🇧🏴🤓
# 1            All over North America                        Wolverine 2018💥
# 2               Whistler, BC CANADA                      Rob Palm Whistler
# 3                       Roma, Lazio                                Mariano
# 4    Frankfurt am Main, Deutschland                         Torsten Larbig
# ..                              ...                                    ...
# 513              West Cork, Ireland                              Cat Tobin
# 514                 Chapel Hill, NC  The third John D. Martin from the sun
# 515                                                          Rusty Colbert
# 516                                                                 austin
# 517              Massachusetts, USA                            Gina Martin
#
#      pinned_tweet_id                                  profile_image_url  \
# 0                NaN  http://pbs.twimg.com/profile_images/9239243429...
# 1                NaN  http://pbs.twimg.com/profile_images/8552445716...
# 2                NaN  http://pbs.twimg.com/profile_images/9640798322...
# 3                NaN  http://pbs.twimg.com/profile_images/3114299697...
# 4                NaN  http://pbs.twimg.com/profile_images/9697051416...
# ..               ...                                                ...
# 513              NaN  http://pbs.twimg.com/profile_images/7831096645...
# 514              NaN  http://pbs.twimg.com/profile_images/9638442277...
# 515              NaN  http://pbs.twimg.com/profile_images/7971210462...
# 516              NaN  http://pbs.twimg.com/profile_images/9327526221...
# 517              NaN  http://pbs.twimg.com/profile_images/9844567586...
#
#      protected                                     public_metrics  \
# 0        False  {'followers_count': 790, 'following_count': 32...
# 1        False  {'followers_count': 16039, 'following_count': ...
# 2        False  {'followers_count': 7618, 'following_count': 7...
# 3        False  {'followers_count': 388, 'following_count': 67...
# 4        False  {'followers_count': 19677, 'following_count': ...
# ..         ...                                                ...
# 513      False  {'followers_count': 1151, 'following_count': 6...
# 514      False  {'followers_count': 2172, 'following_count': 1...
# 515      False  {'followers_count': 168, 'following_count': 73...
# 516      False  {'followers_count': 193, 'following_count': 66...
# 517      False  {'followers_count': 260, 'following_count': 45...
#
#                          url         username  verified  withheld  label
# 0    https://t.co/e5t6p9w7D8       EmmaDingle     False       NaN  human
# 1                       None        Wolv_2018     False       NaN    bot
# 2     http://t.co/7gh2Iu1AT4  RobPalmWhistler     False       NaN  human
# 3                       None       Marianocrt     False       NaN    bot
# 4    https://t.co/VRgsX8eVR2       herrlarbig     False       NaN  human
# ..                       ...              ...       ...       ...    ...
# 513  https://t.co/BgFtjCD2q9           CatTHM     False       NaN  human
# 514  https://t.co/80qIwR30Z7           jdmar3     False       NaN  human
# 515                     None     RustyColbert     False       NaN  human
# 516                     None        Aschmigel     False       NaN  human
# 517                     None  GinaMar13390404     False       NaN  human
#
# [518 rows x 15 columns]

# %%
df.dtypes
# Out:
# created_at           datetime64[ns, UTC]
# description                       object
# entities                          object
# id                                object
# location                          object
# name                              object
# pinned_tweet_id                  float64
# profile_image_url                 object
# protected                           bool
# public_metrics                    object
# url                               object
# username                          object
# verified                            bool
# withheld                         float64
# label                             object
# dtype: object

# %%
# Change created at to Unix epoch time in seconds
df["created_at"] = pd.to_datetime(df["created_at"]).astype("int64") // 10**9 # Convert to seconds

# Drop columns with urls or identifying information (username, id, etc)
df.drop(columns=['entities', 'id', 'profile_image_url', 'url'])
df.head()
# Out:
#    created_at                                        description  \
# 0           1  Strategic Creative Social Media & Community En...
# 1           1  Injustice and corruption make me really mad. I...
# 2           1  Whistler REALTOR® specializing in mountain lif...
# 3           1  O scrivi Italia o scrivi libertà. Due termini ...
# 4           1  Education, Flaneur, Digitalisation—Tweets Germ...
#
#                                             entities                   id  \
# 0  {'url': {'urls': [{'url': 'https://t.co/e5t6p9...           u602249341
# 1                      {'description': {'urls': []}}  u797617218511060992
# 2  {'url': {'urls': [{'url': 'http://t.co/7gh2Iu1...           u889925474
# 3                      {'description': {'urls': []}}            u96435556
# 4  {'url': {'urls': [{'url': 'https://t.co/VRgsX8...            u16905397
#
#                          location                    name  pinned_tweet_id  \
# 0                 London - mostly  Emma Dingle🐧🏳️‍🌈🇪🇺🇬🇧🏴🤓              NaN
# 1          All over North America         Wolverine 2018💥              NaN
# 2             Whistler, BC CANADA       Rob Palm Whistler              NaN
# 3                     Roma, Lazio                 Mariano              NaN
# 4  Frankfurt am Main, Deutschland          Torsten Larbig              NaN
#
#                                    profile_image_url  protected  \
# 0  http://pbs.twimg.com/profile_images/9239243429...      False
# 1  http://pbs.twimg.com/profile_images/8552445716...      False
# 2  http://pbs.twimg.com/profile_images/9640798322...      False
# 3  http://pbs.twimg.com/profile_images/3114299697...      False
# 4  http://pbs.twimg.com/profile_images/9697051416...      False
#
#                                       public_metrics                      url  \
# 0  {'followers_count': 790, 'following_count': 32...  https://t.co/e5t6p9w7D8
# 1  {'followers_count': 16039, 'following_count': ...                     None
# 2  {'followers_count': 7618, 'following_count': 7...   http://t.co/7gh2Iu1AT4
# 3  {'followers_count': 388, 'following_count': 67...                     None
# 4  {'followers_count': 19677, 'following_count': ...  https://t.co/VRgsX8eVR2
#
#           username  verified  withheld  label
# 0       EmmaDingle     False       NaN  human
# 1        Wolv_2018     False       NaN    bot
# 2  RobPalmWhistler     False       NaN  human
# 3       Marianocrt     False       NaN    bot
# 4       herrlarbig     False       NaN  human

# %%
print(df[df['withheld'].notna()])
print(df[df['pinned_tweet_id'].notna()])
# Out:
# Empty DataFrame
# Columns: [created_at, description, entities, id, location, name, pinned_tweet_id, profile_image_url, protected, public_metrics, url, username, verified, withheld, label]
# Index: []
# Empty DataFrame
# Columns: [created_at, description, entities, id, location, name, pinned_tweet_id, profile_image_url, protected, public_metrics, url, username, verified, withheld, label]
# Index: []

# %%
twi_path = os.path.join(os.getcwd(), "label.csv")

test_df = pd.read_csv(twi_path)
test_df.shape

# We'll narrow the dataset down to 5000 bots and 5000 normal users, the dataset file should be ~ 1 GB
# Out:
# (1000000, 2)
